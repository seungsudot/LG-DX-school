# %%
from selenium import webdriver

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup as bs
import pandas as pd
from tqdm import tqdm

# %%
url  = 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EC%A7%91%EC%95%88%EC%9D%BC%20%EC%A0%9C%EC%9D%BC&t=1736734776191&em=1'

# %%
driver = webdriver.Chrome()
driver.get(url)
driver.implicitly_wait(10)

# %%
select = driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap>a')
len(select)

select[3].click()

# %%
cafe_url_list = []
cafe_url_list = [i.get_attribute('href') for i in driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap>a')]

# %%
cafe_url_list
# Out:
# ['https://cafe.naver.com/madmanina?iframe_url=%2FArticleRead.nhn%3Fclubid%3D21219274%26articleid%3D85838%26art%3DaW50ZXJuYWwtY2FmZS13ZWItc2VjdGlvbi1zZWFyY2gtbGlzdA.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiYXJ0aWNsZUlkIjo4NTgzOCwiY2FmZVVybCI6Im1hZG1hbmluYSIsImlzc3VlZEF0IjoxNzM2NzQ2MDU1NTQ3fQ.k64zBkh5gkqXoJ9i_jDoXUm20qyBE4D8g22IDm6o9uM%26query%3D%25EC%25A7%2591%25EC%2595%2588%25EC%259D%25BC%2520%25EC%25A0%259C%25EC%259D%25BC',
#  'https://cafe.naver.com/madmanina',
#  'https://cafe.naver.com/tlsxh?iframe_url=%2FArticleRead.nhn%3Fclubid%3D25257486%26articleid%3D3400164%26art%3DaW50ZXJuYWwtY2FmZS13ZWItc2VjdGlvbi1zZWFyY2gtbGlzdA.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiYXJ0aWNsZUlkIjozNDAwMTY0LCJjYWZlVXJsIjoidGxzeGgiLCJpc3N1ZWRBdCI6MTczNjc0NjA1NTU1MH0.a6PF7G1zEvO7mjUGkLsrSy7QGTBSU4iIpkUlU9mdtgM%26query%3D%25EC%25A7%2591%25EC%2595%2588%25EC%259D%25BC%2520%25EC%25A0%259C%25EC%259D%25BC',
#  'https://cafe.naver.com/tlsxh',
# ...

# %%
for i in tqdm(range(len(titles))):
    titles[i].click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 for i in tqdm(range(len(titles))):
#       2     titles[i].click()
#
# NameError: name 'titles' is not defined

# %%
titles = []
dates = []
contents = []
reviews = []

#for i in tqdm(range(len(cafe_url_list))):
for i in tqdm(range(0,1)):
    title = ''
    date = ''
    content = ''
    review = []
    
    driver.get(cafe_url_list[i]) # URL 검색
    time.sleep(1.5)

    cnt = 0
    while True:
        try:
            driver.switch_to.frame('cafe_main') # iframe 스위치
            break
        except:
            print("iframe 로딩중")
            time.sleep(0.5)
            cnt += 1
            if cnt > 5:
                break
    
    cnt = 0
    while True:
        try:
            title = driver.find_element(By.CSS_SELECTOR, 'h3.title_text').text
            date = driver.find_element(By.CSS_SELECTOR, 'span.date').text
            date = date[:10] # 날짜 슬라이싱
            content = driver.find_element(By.CSS_SELECTOR, 'div.se-module.se-module-text').text
            rvws = driver.find_elements(By.CSS_SELECTOR, '.text_comment')

            for j in range(0,len(rvws)):
                review.append(rvws[j].text)
                #print(reviews[j])
            break # 이상없이 실행됐으면 while문 빠져나가기
        except:
            break
            # print("로딩중") # 로딩중으로 인해 오류뜨면 로딩중 출력
            # time.sleep(0.5)
            # cnt += 1
            # if cnt > 5:
            #     break
                
    print(title, date, content[:10], len(review))

    titles.append(title)
    dates.append(date)
    contents.append(content)
    reviews.append(review)

print("완료!")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.08s/it]
# 집안일 제일 싫은 거ㅠㅠ 2025.01.02 집안일은 다 별로긴 14
# 완료!

# %%
reviews
# Out:
# [['아...저를 보는 느낌....저는\n저녁에 퇴근하고 샤워 후에 결심과 다짐을 하고 이쁘게 접어놓고 남편보고 정리하라 하네요^^',
#   '저는 빨래 접는게 너무 싫어요ㅠㅠ',
#   '저도 옷정리요. 계절 바뀌는게 넘 싫어요.\n옷장정리가 젤루 어렵고 귀찮아요....',
#   '저도 계절별 옷 정리할 때가 제일 힘들어요ㅠㅠㅠ',
#   '엄청.. 쌓이면.. 진짜 스트레스 장난아니에요 하하 ㅠㅠㅠ',
#   '이러다 거실 다 채우겠어요ㅋㅋㅋㅋ',
#   '옷정리 넘 귀찮죠,,',
#   '입고 빨고 입고 빨고 매일 전쟁이네요ㅠㅋㅋ',
#   '캬캬캬. 전 ㅋㅋㅋ 다 시른데 ㅠㅡㅠ\n\n집에오자마자 ㅋㅋㅋ 버릴 옷 분리 하고 빨래 돌려야죠.ㅠ헥헥 .',
#   '저도 다 싫어요 크크',
#   '아이고 ㅜㅜ 쌓인 옷 보면 한숨 푹 나오죠 ㅋㅋㅋㅋ.. 막상 치우면 또 개운',
#   '치워야 개운할 텐데 안 치우니 개운하지가 않네요ㅋㅋㅋ',
#   '저두요~\n건조되서 접어서 나오는 건조기가 개발되었으면 좋겠어요!',
#   '그런 거 있으면 아무리 비싸도 살 거 같아요ㅋㅋㅋㅋㅋ']]

# %%
data = {
    'title' : titles,
    'contents' : contents,
    'date' : dates,
    'reviews' : reviews
}

dataDF = pd.DataFrame(data)

dataDF.to_csv("카페 데이터.csv", encoding='utf-8-sig')

# %%
url  = 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EC%A7%91%EC%95%88%EC%9D%BC%20%EC%A0%9C%EC%9D%BC&t=1736734776191&em={}'

driver = webdriver.Chrome()
driver.get(url)
driver.implicitly_wait(10)

cafe_url_list = []
cafe_url_list = [i.get_attribute('href') for i in driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap+a')]

# %%
len(cafe_url_list)
# Out:
# 4

# %%
cafe_url_list = []
cafe_url_list = [i.get_attribute('href') for i in driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap>a')]

# %%
titles = []
dates = []
contents = []
reviews = []

for i in tqdm(range(len(cafe_url_list))):
    title = ''
    date = ''
    content = ''
    review = []
    
    driver.get(cafe_url_list[i]) # URL 검색
    time.sleep(1.5)

    cnt = 0
    while True:
        try:
            driver.switch_to.frame('cafe_main') # iframe 스위치
            break
        except:
            print("iframe 로딩중")
            time.sleep(0.5)
            cnt += 1
            if cnt > 5:
                break
    
    cnt = 0
    while True:
        try:
            title = driver.find_element(By.CSS_SELECTOR, 'h3.title_text').text
            date = driver.find_element(By.CSS_SELECTOR, 'span.date').text
            date = date[:10] # 날짜 슬라이싱
            content = driver.find_element(By.CSS_SELECTOR, 'div.se-module.se-module-text').text
            rvws = driver.find_elements(By.CSS_SELECTOR, 'span.text_comment')

            for j in range(0,len(rvws)):
                review.append(preprocess_sentence_kr(rvws[j].text))
                #print(reviews[j])
            break # 이상없이 실행됐으면 while문 빠져나가기
        except:
            break
            # print("로딩중") # 로딩중으로 인해 오류뜨면 로딩중 출력
            # time.sleep(0.5)
            # cnt += 1
            # if cnt > 5:
            #     break
                
    print(title, date, content[:10], len(review))

    titles.append(title)
    dates.append(date)
    contents.append(content)
    reviews.append(review)

print("완료!")
# Out:
#   4%|███▍                                                                               | 1/24 [00:03<01:22,  3.59s/it]
# 귀찮은 집안일 2024.12.23 주말 동안 밀린 빨 0
#   8%|██████▉                                                                            | 2/24 [00:15<03:11,  8.71s/it]
#    0
#  12%|██████████▍                                                                        | 3/24 [00:18<02:01,  5.77s/it]
# 집안일 2024.11.05 나와 당신의 저작권 0
#  17%|█████████████▊                                                                     | 4/24 [00:31<02:51,  8.58s/it]
#    0
#  21%|█████████████████▎                                                                 | 5/24 [00:33<02:00,  6.34s/it]
# 집안일 어떤 것 좋아하세요? 2024.12.21 집안일 정말 귀찮고 0
#  25%|████████████████████▊                                                              | 6/24 [00:45<02:31,  8.42s/it]
#    0
#  29%|████████████████████████▏                                                          | 7/24 [00:48<01:49,  6.44s/it]
# ...

# %%
url  = 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EC%A7%91%EC%95%88%EC%9D%BC%20%EC%A0%9C%EC%9D%BC&t=1736734776191&em={}'

driver = webdriver.Chrome()
driver.get(url)
driver.implicitly_wait(10)

cafe_url_list = []
cafe_url_list = [i.get_attribute('href') for i in driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap>a')]

# %%
titles = []
dates = []
contents = []
reviews = []

for i in tqdm(range(len(cafe_url_list))):
    title = ''
    date = ''
    content = ''
    review = []
    
    driver.get(cafe_url_list[i]) # URL 검색
    time.sleep(1.5)

    cnt = 0
    while True:
        try:
            driver.switch_to.frame('cafe_main') # iframe 스위치
            break
        except:
            print("iframe 로딩중")
            time.sleep(0.5)
            cnt += 1
            if cnt > 5:
                break
    
    cnt = 0
    while True:
        try:
            title = driver.find_element(By.CSS_SELECTOR, 'h3.title_text').text
            date = driver.find_element(By.CSS_SELECTOR, 'span.date').text
            date = date[:10] # 날짜 슬라이싱
            content = driver.find_element(By.CSS_SELECTOR, 'div.se-module.se-module-text').text
            rvws = driver.find_elements(By.CSS_SELECTOR, 'div.comment_text_box')

            for j in range(0,len(rvws)):
                review.append(preprocess_sentence_kr(rvws[j].text))
                #print(reviews[j])
            break # 이상없이 실행됐으면 while문 빠져나가기
        except:
            break
            # print("로딩중") # 로딩중으로 인해 오류뜨면 로딩중 출력
            # time.sleep(0.5)
            # cnt += 1
            # if cnt > 5:
            #     break
                
    print(title, date, content[:10], len(review))

    titles.append(title)
    dates.append(date)
    contents.append(content)
    reviews.append(review)

print("완료!")

driver.quit()
# Out:
#   4%|███▍                                                                               | 1/24 [00:02<01:03,  2.75s/it]
# 집안일 제일 싫은 거ㅠㅠ 2025.01.02 집안일은 다 별로긴 0
#   8%|██████▉                                                                            | 2/24 [00:15<03:08,  8.59s/it]
#    0
#  12%|██████████▍                                                                        | 3/24 [00:18<02:04,  5.91s/it]
# 제일 하기 싫은 집안일 베스트 5 2024.12.06 안녕하세요, 오랫만 0
#  17%|█████████████▊                                                                     | 4/24 [00:31<02:54,  8.70s/it]
#    0
#  21%|█████████████████▎                                                                 | 5/24 [00:33<02:04,  6.54s/it]
# 제일 힘든 집안일 2025.01.10 여러분은 어떤 집안 0
#  25%|████████████████████▊                                                              | 6/24 [00:46<02:37,  8.72s/it]
#    0
#  29%|████████████████████████▏                                                          | 7/24 [00:49<01:56,  6.87s/it]
# ...

# %%
data = {
    'title' : titles,
    'contents' : contents,
    'date' : dates,
    'reviews' : reviews
}

dataDF = pd.DataFrame(data)

dataDF.to_csv("카페 데이터3.csv", encoding='utf-8-sig')

# %%
driver = webdriver.Chrome()
url  = 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EC%A7%91%EC%95%88%EC%9D%BC%20%EC%A0%9C%EC%9D%BC&t=1736734776191&em=3'
driver.get(url)
driver.implicitly_wait(10)

# %%
driver = webdriver.Chrome()

url  = 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EC%A7%91%EC%95%88%EC%9D%BC%20%EC%A0%9C%EC%9D%BC&t=1736734776191&em=3'
driver.get(url)
driver.implicitly_wait(10)

url_list = []
url_list = [i.get_attribute('href') for i in driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap+a')]

# %%
url_list
# Out:
# ['https://cafe.naver.com/madmanina?iframe_url=%2FArticleRead.nhn%3Fclubid%3D21219274%26articleid%3D85838%26art%3DaW50ZXJuYWwtY2FmZS13ZWItc2VjdGlvbi1zZWFyY2gtbGlzdA.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiYXJ0aWNsZUlkIjo4NTgzOCwiY2FmZVVybCI6Im1hZG1hbmluYSIsImlzc3VlZEF0IjoxNzM2NzQ1OTEyNzE3fQ.9R_o9br6ge8dhziK6eqAbnR8mfxDE62tjqg54xrZYhI%26query%3D%25EC%25A7%2591%25EC%2595%2588%25EC%259D%25BC%2520%25EC%25A0%259C%25EC%259D%25BC',
#  'https://cafe.naver.com/mokammamheart?iframe_url=%2FArticleRead.nhn%3Fclubid%3D28147845%26articleid%3D398456%26art%3DaW50ZXJuYWwtY2FmZS13ZWItc2VjdGlvbi1zZWFyY2gtbGlzdA.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiYXJ0aWNsZUlkIjozOTg0NTYsImNhZmVVcmwiOiJtb2thbW1hbWhlYXJ0IiwiaXNzdWVkQXQiOjE3MzY3NDU5MTI3MjZ9.hEt5a02Is-ZfPAeu6uFi9ZfhAp6U6HG0RjK03pCwsdY%26query%3D%25EC%25A7%2591%25EC%2595%2588%25EC%259D%25BC%2520%25EC%25A0%259C%25EC%259D%25BC',
# ...

# %%
titles = []
dates = []
contents = []
reviews = []

for i in tqdm(range(len(url_list))):
    title = ''
    date = ''
    content = ''
    review = []
    
    driver.get(url_list[i]) # URL 검색
    time.sleep(1.5)

    cnt = 0
    while True:
        try:
            driver.switch_to.frame('cafe_main') # iframe 스위치
            break
        except:
            print("iframe 로딩중")
            time.sleep(0.5)
            cnt += 1
            if cnt > 5:
                break
    
    cnt = 0
    while True:
        try:
            title = driver.find_element(By.CSS_SELECTOR, 'h3.title_text').text
            date = driver.find_element(By.CSS_SELECTOR, 'span.date').text
            date = date[:10] # 날짜 슬라이싱
            content = driver.find_element(By.CSS_SELECTOR, 'div.se-module.se-module-text').text
            
            review_elements = driver.find_elements(By.CSS_SELECTOR, 'div.comment_text_box') 
            reviews_text = "\n".join([review.text 
                                  for review in review_elements]) 
        
        except Exception as e:
            print(f"리뷰 추출 실패 for {i}: {e}")
        time.sleep(1)
    
          
                
    print(title, date, content[:10], len(review))

    titles.append(title)
    dates.append(date)
    contents.append(content)
    reviews.append(review_text)

print("완료!")

driver.quit()

# %%
data = {
    'title' : titles,
    'contents' : contents,
    'date' : dates,
    'reviews' : reviews
}

dataDF = pd.DataFrame(data)

dataDF.to_csv("카페 데이터_test.csv", encoding='utf-8-sig')

# %% [markdown]
# #### 페이지 바꾸며 추출

# %%
driver = webdriver.Chrome()

# 빈 리스트 생성
cafe_url_list = []

# 숫자를 1부터 100까지 바꾸며 URL 접근
for i in tqdm(range(1, 101)):
    url = f'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%EC%A7%91%EC%95%88%EC%9D%BC%20%EC%A0%9C%EC%9D%BC&t=1736739634816&p={i}'
    
    driver.get(url)
    
    # 페이지 로드를 기다리기 위해 time.sleep 사용
    time.sleep(1)  # 3초 대기 (필요에 따라 조정 가능)
    
    # 요소에서 링크를 가져와 리스트에 추가
    cafe_url_list += [element.get_attribute('href') for element in driver.find_elements(By.CSS_SELECTOR, '.article_item_wrap+a')]

    time.sleep(1)

# 수집한 URL 출력
print(cafe_url_list)

# WebDriver 종료
driver.quit()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:57<00:00,  2.38s/it]
# ...

# %%
len(cafe_url_list)
# Out:
# 528

# %%
titles = []
dates = []
contents = []
reviews = []

for i in tqdm(range(len(cafe_url_list[1,3]))):
    title = ''
    date = ''
    content = ''
    review = []
    
    driver.get(cafe_url_list[i]) # URL 검색
    time.sleep(1.5)

    cnt = 0
    while True:
        try:
            driver.switch_to.frame('cafe_main') # iframe 스위치
            break
        except:
            print("iframe 로딩중")
            time.sleep(0.5)
            cnt += 1
            if cnt > 5:
                break
    
    cnt = 0
    while True:
        try:
            title = driver.find_element(By.CSS_SELECTOR, 'h3.title_text').text
            date = driver.find_element(By.CSS_SELECTOR, 'span.date').text
            date = date[:10] # 날짜 슬라이싱
            content = driver.find_element(By.CSS_SELECTOR, 'div.se-module.se-module-text').text
            rvws = driver.find_elements(By.CSS_SELECTOR, 'div.comment_text_box')

            for j in range(0,len(rvws)):
                review.append(preprocess_sentence_kr(rvws[j].text))
                #print(reviews[j])
            break # 이상없이 실행됐으면 while문 빠져나가기
        except:
            break
            # print("로딩중") # 로딩중으로 인해 오류뜨면 로딩중 출력
            # time.sleep(0.5)
            # cnt += 1
            # if cnt > 5:
            #     break
                
    print(title, date, content[:10], len(review))

    titles.append(title)
    dates.append(date)
    contents.append(content)
    reviews.append(review)

print("완료!")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 6
#       3 contents = []
#       4 reviews = []
# ----> 6 for i in tqdm(range(len(cafe_url_list[1,3]))):
#       7     title = ''
#       8     date = ''
#
# TypeError: list indices must be integers or slices, not tuple
